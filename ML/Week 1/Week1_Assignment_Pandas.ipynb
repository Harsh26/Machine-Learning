# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.shape
# Out:
# (418, 12)

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for col in df:
    print(df[col].unique())
# Out:
# [ 892  893  894  895  896  897  898  899  900  901  902  903  904  905
#   906  907  908  909  910  911  912  913  914  915  916  917  918  919
#   920  921  922  923  924  925  926  927  928  929  930  931  932  933
#   934  935  936  937  938  939  940  941  942  943  944  945  946  947
#   948  949  950  951  952  953  954  955  956  957  958  959  960  961
#   962  963  964  965  966  967  968  969  970  971  972  973  974  975
#   976  977  978  979  980  981  982  983  984  985  986  987  988  989
#   990  991  992  993  994  995  996  997  998  999 1000 1001 1002 1003
#  1004 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017
#  1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031
#  1032 1033 1034 1035 1036 1037 1038 1039 1040 1041 1042 1043 1044 1045
#  1046 1047 1048 1049 1050 1051 1052 1053 1054 1055 1056 1057 1058 1059
#  1060 1061 1062 1063 1064 1065 1066 1067 1068 1069 1070 1071 1072 1073
# ...

# %%
for col in df:
    col_list = df[col].isnull().tolist()
    #print(col_list)
    for element in col_list:
        if element == True:
            print(col)
            break
# Out:
# Age
# Fare
# Cabin

# %%
print(df.describe(include=['int64', 'float64']))
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
null_vals = 0
tar_col = None

for col in df:
    print(col, df[col].isnull().sum(), sep=':')
    
    if df[col].isnull().sum() > null_vals:
        null_vals = df[col].isnull().sum()
        tar_col = col

print(tar_col)

if tar_col is not None:
    df = df.drop(tar_col, axis=1)

df
# Out:
# PassengerId:0
# Survived:0
# Pclass:0
# Name:0
# Sex:0
# Age:86
# SibSp:0
# Parch:0
# Ticket:0
# Fare:1
# Cabin:327
# Embarked:0
# Cabin
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# ...

# %%
print(df.describe(include='all').dtypes)
# Out:
# PassengerId    float64
# Survived       float64
# Pclass         float64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
males = 0
females = 0

for row in df['Sex']:
        if row == 'male':
            males += 1
        else:
            females += 1
print('female / male = ', females, '/', males, sep = ' ')
print('Sex Ratio:', females / males, sep=" ")
# Out:
# female / male =  152 / 266
# Sex Ratio: 0.5714285714285714

# %%
# Sex ratio by value_count()

mf = df['Sex'].value_counts()

# print(mf)
# print(list(mf))

mfl = list(mf)

xy = mfl[0]
xx = mfl[1]

print('Sex Ratio:', xx / xy, sep=" ")
# Out:
# Sex Ratio: 0.5714285714285714

# %%
survived = df['Survived'].sum()
print('No. of people survived = ', survived)
# Out:
# No. of people survived =  152

# %%
maxage = (df['Age'].max())
minage = (df['Age'].min())

print(maxage, minage, sep = " ")
# Out:
# 76.0 0.17

# %%
# Very inefficent method!! to print row
# df = df.reset_index()

# for row in df.iterrows():
#    print(row)
#    if row['Age'] == maxage:
#        print('Max age row: \n',row)
    
#    if row['Age'] == minage:
#        print('Min age row: \n',row)

# %%
# Efficent method to print rows

maxageid = df['Age'].idxmax()
minageid = df['Age'].idxmin()

maxagerow = df.loc[maxageid]
minagerow = df.loc[minageid]

print('Max Age row: \n', maxagerow)
print('Min Age row: \n', minagerow)
# Out:
# Max Age row:
#  PassengerId                                                  988
# Survived                                                       1
# Pclass                                                         1
# Name           Cavendish, Mrs. Tyrell William (Julia Florence...
# Sex                                                       female
# Age                                                         76.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                     19877
# Fare                                                       78.85
# Embarked                                                       S
# Name: 96, dtype: object
# Min Age row:
#  PassengerId                                       1246
# Survived                                             1
# Pclass                                               3
# ...

# %%
count2 = 0

for c2 in df['Pclass']:
    if c2 == 2:
        count2 += 1

print(count2)
# Out:
# 93

# %%
sf = 0
sm = 0

for sex, surv in zip(df['Sex'], df['Survived']):
    if surv == 1 and sex == 'female':
            sf += 1
    
    if surv == 1 and sex == 'male':
            sm += 1

print('Females Survived = ', sf)
print('Males Survived = ', sm)
# Out:
# Females Survived =  152
# Males Survived =  0

# %%
p = 0

for surv, fare in zip(df['Survived'], df['Fare']):
    if surv == 1 and fare < 200:
        p += 1

print('Persons survived with less fare = ', p)
# Out:
# Persons survived with less fare =  140
